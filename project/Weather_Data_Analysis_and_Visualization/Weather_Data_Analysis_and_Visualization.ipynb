# %% [markdown]
# Weather Data Analysis and Visualization

# %% [markdown]
# Team members:
# 1) Mizanur Rahman: 2204063
# 2) Abu Said Mia: 2204074
# 3) Jayed hoshen: 2204076

# %%
#=========import section==========
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('data.csv')

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# ======================>>> Some Analysis of full Data sheet <<<====================

# %%
#<<1>>---------- Provides basic information about the dataframe ----------
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# <<2>>---------- Count Weather Frequency ------------
loc = df['Weather'].value_counts()
dfWeather = pd.DataFrame(loc)
dfWeather = dfWeather.reset_index()
dfWeather.columns = ['Weather', 'Frequency']

dfWeather
# Out:
#                                     Weather  Frequency
# 0                              Mainly Clear       2106
# 1                             Mostly Cloudy       2069
# 2                                    Cloudy       1728
# 3                                     Clear       1326
# 4                                      Snow        390
# 5                                      Rain        306
# 6                              Rain Showers        188
# 7                                       Fog        150
# 8                                  Rain,Fog        116
# 9                               Drizzle,Fog         80
# 10                             Snow Showers         60
# 11                                  Drizzle         41
# 12                                 Snow,Fog         37
# 13                        Snow,Blowing Snow         19
# 14                                Rain,Snow         18
# 15               Thunderstorms,Rain Showers         16
# ...

# %%
#<<3>>---------- Display a bar-chart of showing of weather conditions ----------
keep = dfWeather[dfWeather['Frequency'] > 100]

color = ['#123524', '#3E7B27', '#EFE3C2', '#85A947', '#D39D55']
plt.subplots(figsize = (14, 6))
plt.bar(keep['Weather'], keep['Frequency'], color = color, width = 0.6, edgecolor = 'black', linewidth = 1, alpha = 0.6)
plt.xlabel('Weather')
plt.ylabel('Frequency')
plt.title("Showing Weather Conditions")
for i, v in enumerate(keep['Frequency']):
    plt.text(i, v, str(v), color = 'orange', ha = 'center', va = 'bottom')
plt.show()

# %%
#<<4>>--------- Total number of unique values in each column -----------
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
#<<5>>------- Total number of non-null values in each column ---------
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
#<<6>>--------- Find the number of times when the "Weather is exactly Clear" --------
df[df.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#<<7>>--------- Find the number of times when the "Weather is exactly Fog" --------
df[df['Weather'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#<<7>>--------- Find the number of times when the "Wind Speed is exactly 4 km/h" --------
df[df['Wind Speed_km/h'] ==  4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
#<<8>>--------- Find the number of times when the "Minimum, Maximum and Average Wind Speed" --------
mn = df['Wind Speed_km/h'].min()
mx = df['Wind Speed_km/h'].max()
avg = df['Wind Speed_km/h'].mean()
print("---- Wind Speed km/h -----\n")
print("Minimum = ", mn)
print("Maximum = ", mx)
print("Average = ", avg)
# Out:
# ---- Wind Speed km/h -----
#
# Minimum =  0
# Maximum =  83
# Average =  14.94546903460838

# %%
#<<9>>--------- Find the number of times when the "Minimum, Maximum and Average Visibility_km" --------
mn = df['Visibility_km'].min()
mx = df['Visibility_km'].max()
avg = df['Visibility_km'].mean()
print("----- Visibility km ----\n")
print("Minimum = ", mn)
print("Maximum = ", mx)
print("Average = ", avg)

# visibility greater than average
print("\n---------------- Visibility greater than average value -----------")
df[df['Visibility_km'] > avg]

#--------- Line chart of Date/Time and Visibility in this year -----------
# plt.subplots(figsize = (15, 6))
# plt.plot(df['Date/Time'], df['Visibility_km'])
# plt.title('Visibility (km) in this Year')
# plt.xlabel('Date/Time')
# plt.ylabel('Visibility_km')
# plt.show()
# Out:
# ----- Visibility km ----
#
# Minimum =  0.2
# Maximum =  48.3
# Average =  27.664446721311478
#
# ---------------- Visibility greater than average value -----------
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# ...

# %%
#<<10>>--------- Find the number of times when the "Minimum, Maximum and Average Temperature" --------
mn = df['Temp_C'].min()
mx = df['Temp_C'].max()
avg = df['Temp_C'].mean()
print("----- Temperature ----\n")
print("Minimum = ", mn)
print("Maximum = ", mx)
print("Average = ", avg)

#--------- Line chart of Date/Time and Temperature in this year -----------
plt.subplots(figsize = (15, 6))
plt.plot(df['Date/Time'], df['Temp_C'])
plt.title('Temperature in 2012')
plt.xlabel('Date/Time')
plt.ylabel('Temperature')
plt.show()
# Out:
# ----- Temperature ----
#
# Minimum =  -23.3
# Maximum =  33.0
# Average =  8.798144353369764

# %%
#<<11>>--------- Find the number of times when the "Minimum, Maximum and Average Press_kPa" --------
mn = df['Press_kPa'].min()
mx = df['Press_kPa'].max()
avg = df['Press_kPa'].mean()
print("----- Pressure kPa ----\n")
print("Minimum = ", mn)
print("Maximum = ", mx)
print("Average = ", avg)

# Pressure greater than average
print("\n---------------- Pressure greater than average value -----------")
df[df['Press_kPa'] > avg]
# Out:
# ----- Pressure kPa ----
#
# Minimum =  97.52
# Maximum =  103.65
# Average =  101.05162340619307
#
# ---------------- Pressure greater than average value -----------
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012 0:00    -1.8              -3.9         86                4
# 1       1/1/2012 1:00    -1.8              -3.7         87                4
# 2       1/1/2012 2:00    -1.8              -3.4         89                7
# 3       1/1/2012 3:00    -1.5              -3.2         88                6
# 4       1/1/2012 4:00    -1.5              -3.3         88                7
# ...               ...     ...               ...        ...              ...
# 8765  12/31/2012 5:00   -10.2             -12.4         84                6
# 8766  12/31/2012 6:00    -9.7             -11.7         85                4
# 8767  12/31/2012 7:00    -9.3             -11.3         85                0
# ...

# %%
# --------------- Showing a pie chart Where pressure is greater than 50 kPa -----------
y = df['Press_kPa'].value_counts()
dp = pd.DataFrame(y)
dp = dp.reset_index()
dp.columns = ['Press_kPa', 'Frequency']
py = dp[dp['Frequency'] > 50]
plt.pie(py['Frequency'], labels = py['Press_kPa'], textprops = {"fontsize" : 12}, autopct = "%0.2f%%", radius = 1.5)

plt.show()

# %%
#<<12>>--------- Find the number of times when the "Minimum, Maximum and Average Dew Point Temp_C" --------
mn = df['Dew Point Temp_C'].min()
mx = df['Dew Point Temp_C'].max()
avg = df['Dew Point Temp_C'].mean()
print("----- Dew Point Temperature ----\n")
print("Minimum = ", mn)
print("Maximum = ", mx)
print("Average = ", avg)

# Dew Point Temp_C greater than average
print("\n---------------- Dew Point Temperature greater than average value -----------")
df[df['Dew Point Temp_C'] > avg]
# Out:
# ----- Dew Point Temperature ----
#
# Minimum =  -28.5
# Maximum =  24.4
# Average =  2.5552937158469944
#
# ---------------- Dew Point Temperature greater than average value -----------
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 555   1/24/2012 3:00     5.0               3.6         91               19
# 1618  3/8/2012 10:00    12.1               2.9         53               30
# 1619  3/8/2012 11:00    12.7               3.8         55               26
# 1620  3/8/2012 12:00    11.7               4.0         59               20
# 1621  3/8/2012 13:00    11.5               5.2         65               20
# ...              ...     ...               ...        ...              ...
# 8138  12/5/2012 2:00     8.7               7.1         90               24
# 8139  12/5/2012 3:00     7.8               6.7         93               24
# 8140  12/5/2012 4:00     7.2               4.8         85               15
# ...

# %%
#<<13>>--------- Find all instances when:
    # "Weather is Clear" and "Relative Humidity is greater than 50"
    # or
    # "Visibility is above 40"

df[((df['Weather'] == 'Clear') & (df['Rel Hum_%'] > 50)) | (df.Visibility_km > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
